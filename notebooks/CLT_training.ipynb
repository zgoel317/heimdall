# %%
# !git clone https://github.com/EleutherAI/clt-training
# %cd clt-training
# Out:
# Cloning into 'clt-training'...
# remote: Enumerating objects: 2348, done.
# remote: Counting objects: 100% (970/970), done.
# remote: Compressing objects: 100% (319/319), done.
# remote: Total 2348 (delta 833), reused 700 (delta 651), pack-reused 1378 (from 2)
# Receiving objects: 100% (2348/2348), 1.05 MiB | 2.62 MiB/s, done.
# Resolving deltas: 100% (1669/1669), done.
# /content/clt-training

# %%
# %%file pyproject.toml
# [build-system]
# requires = ["setuptools"]
# build-backend = "setuptools.build_meta"
#
# [project]
# name = "eai-sparsify"
# description = "Sparsify transformers with SAEs and transcoders"
# readme = "README.md"
# requires-python = ">=3.10"
# keywords = ["interpretability", "explainable-ai"]
# license = {text = "MIT License"}
# dependencies = [
#     "accelerate", # For device_map in from_pretrained
#     "datasets",
#     "einops",
#     "hf-xet>=1.1.0",
#     "huggingface-hub",
#     "natsort", # For sorting module names
#     "safetensors",
#     "schedulefree",
#     "simple-parsing",
#     "torch",
#     "transformers",
#     "wandb>=0.19.11",
# ]
# version = "1.1.3"
# [project.optional-dependencies]
# dev = [
#     "pre-commit",
# ]
#
# [project.scripts]
# sparsify = "sparsify.__main__:run"
#
# [[tool.uv.index]]
# name = "pytorch"
# url = "https://download.pytorch.org/whl/cu128"
# explicit = true
# [tool.uv]
# prerelease = "allow"
# override-dependencies = [
#     "vllm ; sys_platform == 'never'",
#     "xformers ; sys_platform == 'never'",
#     "torch ; sys_platform == 'never'",
#     "triton ; sys_platform == 'never'",
# ]
# [tool.uv.sources]
# torch = [
#     { index = "pytorch" },
# ]
# triton = [
#     { index = "pytorch" }
# ]
#
# [tool.pyright]
# include = ["sparsify*"]
# reportPrivateImportUsage = false
#
# [tool.setuptools.packages.find]
# include = ["sparsify*"]
#
# [tool.ruff]
# exclude = ["scripts/*"]
# # Enable pycodestyle (`E`), Pyflakes (`F`), and isort (`I`) codes
# # See https://beta.ruff.rs/docs/rules/ for more possible rules
# select = ["E", "F", "I"]
# # Same as Black.
# line-length = 88
# # Avoid automatically removing unused imports in __init__.py files.
# # Such imports will be flagged with a dedicated message suggesting
# # that the import is either added to the module's __all__ symbol
# ignore-init-module-imports = true
#
# [tool.semantic_release]
# version_variables = ["sparsify/__init__.py:__version__"]
# version_toml = ["pyproject.toml:project.version"]
# assets = []
# build_command_env = []
# commit_message = "{version}\n\nAutomatically generated by python-semantic-release"
# commit_parser = "conventional"
# logging_use_named_masks = false
# major_on_zero = true
# allow_zero_version = true
# no_git_verify = false
# tag_format = "v{version}"
#
# [tool.semantic_release.branches.main]
# match = "(main|master)"
# prerelease_token = "rc"
# prerelease = false
#
# [tool.semantic_release.changelog]
# changelog_file = ""
# exclude_commit_patterns = []
# mode = "init"
# insertion_flag = "<!-- version list -->"
# template_dir = "templates"
#
# [tool.semantic_release.changelog.default_templates]
# changelog_file = "CHANGELOG.md"
# output_format = "md"
# mask_initial_release = false
#
# [tool.semantic_release.changelog.environment]
# block_start_string = "{%"
# block_end_string = "%}"
# variable_start_string = "{{"
# variable_end_string = "}}"
# comment_start_string = "{#"
# comment_end_string = "#}"
# trim_blocks = false
# lstrip_blocks = false
# newline_sequence = "\n"
# keep_trailing_newline = false
# extensions = []
# autoescape = false
#
# [tool.semantic_release.commit_author]
# env = "GIT_COMMIT_AUTHOR"
# default = "semantic-release <semantic-release>"
#
# [tool.semantic_release.commit_parser_options]
# minor_tags = ["feat"]
# patch_tags = ["fix", "perf"]
# other_allowed_tags = ["build", "chore", "ci", "docs", "style", "refactor", "test"]
# allowed_tags = ["feat", "fix", "perf", "build", "chore", "ci", "docs", "style", "refactor", "test"]
# default_bump_level = 0
# parse_squash_commits = false
# ignore_merge_commits = false
#
# [tool.semantic_release.remote]
# name = "origin"
# type = "github"
# ignore_token_for_push = false
# insecure = false
#
# [tool.semantic_release.publish]
# dist_glob_patterns = ["dist/*"]
# upload_to_vcs_release = true
# Out:
# Overwriting pyproject.toml

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.7.12 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv pip install -e .
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 59 packages in 651ms
#    Building eai-sparsify @ file:///content/clt-training
#    Building eai-sparsify @ file:///content/clt-training
# ⠙ Preparing packages... (0/2)
#    Building eai-sparsify @ file:///content/clt-training
# ⠙ Preparing packages... (0/2)
#    Building eai-sparsify @ file:///content/clt-training
# ⠙ Preparing packages... (0/2)
#    Building eai-sparsify @ file:///content/clt-training
# ⠙ Preparing packages... (0/2)
#    Building eai-sparsify @ file:///content/clt-training
# ⠙ Preparing packages... (0/2)
#    Building eai-sparsify @ file:///content/clt-training
#    Building eai-sparsify @ file:///content/clt-training
#    Building eai-sparsify @ file:///content/clt-training
#    Building eai-sparsify @ file:///content/clt-training
#    Building eai-sparsify @ file:///content/clt-training
#    Building eai-sparsify @ file:///content/clt-training
#       Built eai-sparsify @ file:///content/clt-training
# Prepared 2 packages in 1.03s
# Installed 2 packages in 4ms
#  + eai-sparsify==1.1.3 (from file:///content/clt-training)
#  + schedulefree==1.4.1

# %%
# %%file train.sh
# # python -m sparsify openai-community/gpt2 EleutherAI/fineweb-edu-dedup-10b --ctx_len 128 --filter_bos=True \
# python -m sparsify openai-community/gpt2 NeelNanda/pile-10k --ctx_len 128 --filter_bos=True \
# --transcode=True --skip_connection=True \
# --batch_size=4 \
# --hookpoints h.0.mlp h.1.mlp h.2.mlp h.3.mlp h.4.mlp h.5.mlp h.6.mlp h.7.mlp h.8.mlp h.9.mlp h.10.mlp h.11.mlp \
# --run_name gpt2-sweep \
# --cross_layer=12 --coalesce_topk=concat --topk_coalesced=False \
# --post_encoder_scale=True --normalize_io=True \
# --lr 3e-4 \
# --optimizer adam --lr_warmup_steps 50
# Out:
# Writing train.sh

# %%
# !uv pip install -U datasets
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 32 packages in 190ms
# ⠙ Preparing packages... (0/16)
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------     0 B/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------     0 B/63.33 KiB
# dill       ------------------------------     0 B/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------     0 B/63.33 KiB
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------     0 B/63.33 KiB
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 30.88 KiB/63.33 KiB
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 30.88 KiB/63.33 KiB
# dill       ------------------------------ 46.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 30.88 KiB/63.33 KiB
# dill       ------------------------------ 46.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# dill       ------------------------------ 46.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# certifi    ------------------------------ 62.77 KiB/153.96 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# certifi    ------------------------------ 62.77 KiB/153.96 KiB
# ⠙ Preparing packages... (0/16)
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# certifi    ------------------------------ 62.77 KiB/153.96 KiB
# frozenlist ------------------------------     0 B/229.79 KiB
# ⠙ Preparing packages... (0/16)
# packaging  ------------------------------ 14.88 KiB/64.91 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 16.00 KiB/140.16 KiB
# certifi    ------------------------------ 78.67 KiB/153.96 KiB
# fsspec     ------------------------------ 16.00 KiB/189.08 KiB
# propcache  ------------------------------ 16.00 KiB/208.47 KiB
# frozenlist ------------------------------ 16.00 KiB/229.79 KiB
# yarl       ------------------------------ 16.00 KiB/340.80 KiB
# datasets   ------------------------------ 32.00 KiB/480.03 KiB
# huggingface-hub ------------------------------ 14.51 KiB/502.73 KiB
# aiohttp    ------------------------------ 14.91 KiB/1.65 MiB
# hf-xet     ------------------------------ 16.00 KiB/2.92 MiB
# pandas     ------------------------------ 14.88 KiB/11.80 MiB
# numpy      ------------------------------ 16.00 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# packaging  ------------------------------ 46.88 KiB/64.91 KiB
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 32.00 KiB/140.16 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# fsspec     ------------------------------ 32.00 KiB/189.08 KiB
# propcache  ------------------------------ 126.04 KiB/208.47 KiB
# frozenlist ------------------------------ 128.00 KiB/229.79 KiB
# yarl       ------------------------------ 16.00 KiB/340.80 KiB
# datasets   ------------------------------ 77.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 46.51 KiB/502.73 KiB
# aiohttp    ------------------------------ 142.80 KiB/1.65 MiB
# hf-xet     ------------------------------ 121.85 KiB/2.92 MiB
# pandas     ------------------------------ 46.88 KiB/11.80 MiB
# numpy      ------------------------------ 76.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# packaging  ------------------------------ 62.88 KiB/64.91 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 48.00 KiB/140.16 KiB
# fsspec     ------------------------------ 48.00 KiB/189.08 KiB
# propcache  ------------------------------ 206.04 KiB/208.47 KiB
# frozenlist ------------------------------ 229.79 KiB/229.79 KiB
# yarl       ------------------------------ 340.80 KiB/340.80 KiB
# datasets   ------------------------------ 125.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 78.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 895.43 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.12 MiB/2.92 MiB
# pandas     ------------------------------ 46.88 KiB/11.80 MiB
# numpy      ------------------------------ 76.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# packaging  ------------------------------ 62.88 KiB/64.91 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/140.16 KiB
# fsspec     ------------------------------ 48.00 KiB/189.08 KiB
# propcache  ------------------------------ 206.04 KiB/208.47 KiB
# frozenlist ------------------------------ 229.79 KiB/229.79 KiB
# yarl       ------------------------------ 340.80 KiB/340.80 KiB
# datasets   ------------------------------ 141.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 78.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 904.56 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.14 MiB/2.92 MiB
# pandas     ------------------------------ 46.88 KiB/11.80 MiB
# numpy      ------------------------------ 76.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# packaging  ------------------------------ 62.88 KiB/64.91 KiB
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/140.16 KiB
# fsspec     ------------------------------ 48.00 KiB/189.08 KiB
# propcache  ------------------------------ 206.04 KiB/208.47 KiB
# yarl       ------------------------------ 340.80 KiB/340.80 KiB
# datasets   ------------------------------ 141.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 78.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 904.56 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.32 MiB/2.92 MiB
# pandas     ------------------------------ 46.88 KiB/11.80 MiB
# numpy      ------------------------------ 76.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/140.16 KiB
# fsspec     ------------------------------ 48.00 KiB/189.08 KiB
# propcache  ------------------------------ 208.47 KiB/208.47 KiB
# yarl       ------------------------------ 340.80 KiB/340.80 KiB
# datasets   ------------------------------ 141.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 78.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 920.56 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.32 MiB/2.92 MiB
# pandas     ------------------------------ 46.88 KiB/11.80 MiB
# numpy      ------------------------------ 76.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/140.16 KiB
# fsspec     ------------------------------ 63.97 KiB/189.08 KiB
# yarl       ------------------------------ 340.80 KiB/340.80 KiB
# datasets   ------------------------------ 141.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 96.48 KiB/502.73 KiB
# aiohttp    ------------------------------ 920.56 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.32 MiB/2.92 MiB
# pandas     ------------------------------ 46.88 KiB/11.80 MiB
# numpy      ------------------------------ 76.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 64.00 KiB/140.16 KiB
# fsspec     ------------------------------ 63.97 KiB/189.08 KiB
# datasets   ------------------------------ 173.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 96.48 KiB/502.73 KiB
# aiohttp    ------------------------------ 936.56 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.32 MiB/2.92 MiB
# pandas     ------------------------------ 46.88 KiB/11.80 MiB
# numpy      ------------------------------ 76.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# multiprocess ------------------------------ 128.00 KiB/140.16 KiB
# fsspec     ------------------------------ 143.97 KiB/189.08 KiB
# datasets   ------------------------------ 237.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 254.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1011.56 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.88 MiB/2.92 MiB
# pandas     ------------------------------ 110.88 KiB/11.80 MiB
# numpy      ------------------------------ 172.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 159.97 KiB/189.08 KiB
# datasets   ------------------------------ 269.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 254.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1011.56 KiB/1.65 MiB
# hf-xet     ------------------------------ 1.88 MiB/2.92 MiB
# pandas     ------------------------------ 110.88 KiB/11.80 MiB
# numpy      ------------------------------ 172.89 KiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# fsspec     ------------------------------ 175.97 KiB/189.08 KiB
# datasets   ------------------------------ 301.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 334.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1.02 MiB/1.65 MiB
# hf-xet     ------------------------------ 2.11 MiB/2.92 MiB
# pandas     ------------------------------ 126.88 KiB/11.80 MiB
# numpy      ------------------------------ 1.86 MiB/16.15 MiB
# ⠙ Preparing packages... (0/16)
# fsspec     ------------------------------ 175.97 KiB/189.08 KiB
# datasets   ------------------------------ 301.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 334.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1.03 MiB/1.65 MiB
# hf-xet     ------------------------------ 2.66 MiB/2.92 MiB
# pandas     ------------------------------ 126.88 KiB/11.80 MiB
# numpy      ------------------------------ 2.36 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# datasets   ------------------------------ 301.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 334.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1.03 MiB/1.65 MiB
# hf-xet     ------------------------------ 2.81 MiB/2.92 MiB
# pandas     ------------------------------ 126.88 KiB/11.80 MiB
# numpy      ------------------------------ 2.50 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# datasets   ------------------------------ 316.72 KiB/480.03 KiB
# huggingface-hub ------------------------------ 350.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1.06 MiB/1.65 MiB
# hf-xet     ------------------------------ 2.92 MiB/2.92 MiB
# pandas     ------------------------------ 184.39 KiB/11.80 MiB
# numpy      ------------------------------ 3.47 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# datasets   ------------------------------ 316.72 KiB/480.03 KiB
# huggingface-hub ------------------------------ 350.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1.06 MiB/1.65 MiB
# pandas     ------------------------------ 184.39 KiB/11.80 MiB
# numpy      ------------------------------ 3.87 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# datasets   ------------------------------ 316.72 KiB/480.03 KiB
# huggingface-hub ------------------------------ 366.50 KiB/502.73 KiB
# aiohttp    ------------------------------ 1.49 MiB/1.65 MiB
# pandas     ------------------------------ 184.39 KiB/11.80 MiB
# numpy      ------------------------------ 3.87 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# datasets   ------------------------------ 333.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 380.29 KiB/502.73 KiB
# aiohttp    ------------------------------ 1.65 MiB/1.65 MiB
# pandas     ------------------------------ 222.77 KiB/11.80 MiB
# numpy      ------------------------------ 3.99 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# datasets   ------------------------------ 333.47 KiB/480.03 KiB
# huggingface-hub ------------------------------ 380.29 KiB/502.73 KiB
# pandas     ------------------------------ 222.77 KiB/11.80 MiB
# numpy      ------------------------------ 4.02 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# huggingface-hub ------------------------------ 380.29 KiB/502.73 KiB
# pandas     ------------------------------ 238.77 KiB/11.80 MiB
# numpy      ------------------------------ 4.05 MiB/16.15 MiB
# ⠹ Preparing packages... (8/16)
# huggingface-hub ------------------------------ 396.29 KiB/502.73 KiB
# pandas     ------------------------------ 270.88 KiB/11.80 MiB
# numpy      ------------------------------ 4.09 MiB/16.15 MiB
# ⠸ Preparing packages... (12/16)
# huggingface-hub ------------------------------ 462.50 KiB/502.73 KiB
# pandas     ------------------------------ 440.56 KiB/11.80 MiB
# numpy      ------------------------------ 4.13 MiB/16.15 MiB
# ⠸ Preparing packages... (12/16)
# pandas     ------------------------------ 472.56 KiB/11.80 MiB
# numpy      ------------------------------ 4.13 MiB/16.15 MiB
# ⠸ Preparing packages... (12/16)
# pandas     ------------------------------ 520.46 KiB/11.80 MiB
# numpy      ------------------------------ 4.21 MiB/16.15 MiB
# ⠸ Preparing packages... (12/16)
# pandas     ------------------------------ 584.46 KiB/11.80 MiB
# numpy      ------------------------------ 4.29 MiB/16.15 MiB
# ⠸ Preparing packages... (12/16)
# pandas     ------------------------------ 600.56 KiB/11.80 MiB
# numpy      ------------------------------ 4.44 MiB/16.15 MiB
# ⠼ Preparing packages... (13/16)
# pandas     ------------------------------ 616.56 KiB/11.80 MiB
# numpy      ------------------------------ 4.47 MiB/16.15 MiB
# ⠼ Preparing packages... (13/16)
# pandas     ------------------------------ 632.56 KiB/11.80 MiB
# numpy      ------------------------------ 4.55 MiB/16.15 MiB
# ⠼ Preparing packages... (13/16)
# pandas     ------------------------------ 648.56 KiB/11.80 MiB
# numpy      ------------------------------ 4.69 MiB/16.15 MiB
# ⠼ Preparing packages... (13/16)
# pandas     ------------------------------ 680.56 KiB/11.80 MiB
# numpy      ------------------------------ 4.90 MiB/16.15 MiB
# ⠴ Preparing packages... (13/16)
# pandas     ------------------------------ 680.56 KiB/11.80 MiB
# numpy      ------------------------------ 5.00 MiB/16.15 MiB
# ⠴ Preparing packages... (13/16)
# pandas     ------------------------------ 696.56 KiB/11.80 MiB
# numpy      ------------------------------ 5.25 MiB/16.15 MiB
# ⠴ Preparing packages... (13/16)
# pandas     ------------------------------ 696.56 KiB/11.80 MiB
# numpy      ------------------------------ 5.72 MiB/16.15 MiB
# ⠴ Preparing packages... (13/16)
# pandas     ------------------------------ 696.56 KiB/11.80 MiB
# numpy      ------------------------------ 6.39 MiB/16.15 MiB
# ⠦ Preparing packages... (13/16)
# pandas     ------------------------------ 696.56 KiB/11.80 MiB
# numpy      ------------------------------ 7.41 MiB/16.15 MiB
# ⠦ Preparing packages... (13/16)
# pandas     ------------------------------ 696.56 KiB/11.80 MiB
# numpy      ------------------------------ 8.03 MiB/16.15 MiB
# ⠦ Preparing packages... (13/16)
# pandas     ------------------------------ 776.56 KiB/11.80 MiB
# numpy      ------------------------------ 9.37 MiB/16.15 MiB
# ⠦ Preparing packages... (13/16)
# pandas     ------------------------------ 1.22 MiB/11.80 MiB
# numpy      ------------------------------ 10.61 MiB/16.15 MiB
# ⠧ Preparing packages... (13/16)
# pandas     ------------------------------ 1.61 MiB/11.80 MiB
# numpy      ------------------------------ 11.56 MiB/16.15 MiB
# ⠧ Preparing packages... (13/16)
# pandas     ------------------------------ 2.01 MiB/11.80 MiB
# numpy      ------------------------------ 12.95 MiB/16.15 MiB
# ⠧ Preparing packages... (13/16)
# pandas     ------------------------------ 2.17 MiB/11.80 MiB
# numpy      ------------------------------ 13.50 MiB/16.15 MiB
# ⠧ Preparing packages... (13/16)
# pandas     ------------------------------ 2.54 MiB/11.80 MiB
# numpy      ------------------------------ 14.11 MiB/16.15 MiB
# ⠇ Preparing packages... (13/16)
# pandas     ------------------------------ 3.20 MiB/11.80 MiB
# numpy      ------------------------------ 14.11 MiB/16.15 MiB
# ⠇ Preparing packages... (13/16)
# pandas     ------------------------------ 3.88 MiB/11.80 MiB
# numpy      ------------------------------ 14.11 MiB/16.15 MiB
# ⠇ Preparing packages... (13/16)
# pandas     ------------------------------ 4.81 MiB/11.80 MiB
# numpy      ------------------------------ 15.73 MiB/16.15 MiB
# ⠇ Preparing packages... (13/16)
# pandas     ------------------------------ 5.83 MiB/11.80 MiB
# numpy      ------------------------------ 16.08 MiB/16.15 MiB
# ⠋ Preparing packages... (13/16)
# pandas     ------------------------------ 6.75 MiB/11.80 MiB
# ⠋ Preparing packages... (13/16)
# pandas     ------------------------------ 6.75 MiB/11.80 MiB
# ⠋ Preparing packages... (13/16)
# pandas     ------------------------------ 8.62 MiB/11.80 MiB
# ⠋ Preparing packages... (13/16)
# pandas     ------------------------------ 8.79 MiB/11.80 MiB
# ⠋ Preparing packages... (13/16)
# pandas     ------------------------------ 8.79 MiB/11.80 MiB
# ⠙ Preparing packages... (14/16)
# ⠙ Preparing packages... (14/16)
# Prepared 16 packages in 1.87s
# Uninstalled 16 packages in 276ms
# Installed 16 packages in 109ms
#  - aiohttp==3.11.15
#  + aiohttp==3.12.13
#  - certifi==2025.4.26
#  + certifi==2025.6.15
#  - datasets==2.14.4
#  + datasets==3.6.0
#  - dill==0.3.7
#  + dill==0.3.8
#  - frozenlist==1.6.0
#  + frozenlist==1.7.0
#  - fsspec==2025.3.2
#  + fsspec==2025.3.0
#  - hf-xet==1.1.2
#  + hf-xet==1.1.4rc5
#  - huggingface-hub==0.32.4
#  + huggingface-hub==0.33.0
#  - multiprocess==0.70.15
#  + multiprocess==0.70.16
#  - numpy==2.0.2
#  + numpy==2.3.0
#  - packaging==24.2
#  + packaging==25.0
#  - pandas==2.2.2
#  + pandas==2.3.0
#  - propcache==0.3.1
#  + propcache==0.3.2
#  - pyarrow==18.1.0
#  + pyarrow==20.0.0
#  - requests==2.32.3
#  + requests==2.32.4
#  - yarl==1.20.0
#  + yarl==1.20.1

# %%
# !bash train.sh
# Out:
# 2025-06-16 16:20:29.445940: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750090829.464299    2623 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750090829.470266    2623 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-16 16:20:29.490564: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# config.json: 100% 665/665 [00:00<00:00, 4.52MB/s]
# model.safetensors: 100% 548M/548M [00:09<00:00, 59.6MB/s]
# README.md: 100% 373/373 [00:00<00:00, 2.60MB/s]
# dataset_infos.json: 100% 921/921 [00:00<00:00, 5.73MB/s]
# (…)-00000-of-00001-4746b8785c874cc7.parquet: 100% 33.3M/33.3M [00:00<00:00, 174MB/s]
# Generating train split: 100% 10000/10000 [00:00<00:00, 37192.68 examples/s]
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 213kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 8.91MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 7.50MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 7.50MB/s]
# Map: 100% 10000/10000 [01:30<00:00, 110.14 examples/s]
# Shuffling dataset with seed 42
# Training on 'NeelNanda/pile-10k' (split 'train')
# Storing model weights in torch.bfloat16
# Initializing SAEs with random seed(s) [0]
# bitsandbytes 8-bit Adam not available, using torch.optim.Adam
# Run `pip install bitsandbytes` for less memory usage.
# Learning rate: 3.00e-04
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 1
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true&ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: rainylty (rainylty-georgia-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/clt-training/wandb/run-20250616_162636-hcsjr692
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gpt2-sweep
# wandb: ⭐️ View project at https://wandb.ai/rainylty-georgia-institute-of-technology/sparsify
# wandb: 🚀 View run at https://wandb.ai/rainylty-georgia-institute-of-technology/sparsify/runs/hcsjr692
# Number of SAE parameters: 464_200_704
# Number of model parameters: 124_439_808
# Training:   0% 0/33909 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# W0616 16:26:41.828000 2623 torch/_inductor/utils.py:1137] [4/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# W0616 16:26:55.598000 2623 torch/_dynamo/convert_frame.py:906] [6/8] torch._dynamo hit config.cache_size_limit (8)
# W0616 16:26:55.598000 2623 torch/_dynamo/convert_frame.py:906] [6/8]    function: 'wrapper' (/content/clt-training/sparsify/utils.py:384)
# W0616 16:26:55.598000 2623 torch/_dynamo/convert_frame.py:906] [6/8]    last reason: 6/0: tensor 'L['top_acts']' size mismatch at index 1. expected 32, actual 288
# W0616 16:26:55.598000 2623 torch/_dynamo/convert_frame.py:906] [6/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0616 16:26:55.598000 2623 torch/_dynamo/convert_frame.py:906] [6/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/torch.compiler_troubleshooting.html.
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# Training:   3% 998/33909 [06:17<3:17:20,  2.78it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:   6% 1998/33909 [12:59<3:12:34,  2.76it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:   9% 2998/33909 [19:57<3:05:56,  2.77it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:  12% 3998/33909 [27:06<2:59:40,  2.77it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:  15% 4998/33909 [34:53<2:54:09,  2.77it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:  18% 5998/33909 [43:54<2:47:50,  2.77it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:  21% 6998/33909 [56:39<2:41:51,  2.77it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:  24% 7998/33909 [1:07:18<2:35:30,  2.78it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:  27% 8998/33909 [1:17:33<2:32:49,  2.72it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/optimizer_0.pt
# Training:  29% 9998/33909 [1:27:53<2:24:07,  2.77it/s]Saving checkpoint
# Saved checkpoints/gpt2-sweep/h.0.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.1.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.2.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.3.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.4.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.5.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.6.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.7.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.8.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.9.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.10.mlp/sae.safetensors
# Saved checkpoints/gpt2-sweep/h.11.mlp/sae.safetensors
# train.sh: line 10:  2623 Killed                  python -m sparsify openai-community/gpt2 NeelNanda/pile-10k --ctx_len 128 --filter_bos=True --transcode=True --skip_connection=True --batch_size=4 --hookpoints h.0.mlp h.1.mlp h.2.mlp h.3.mlp h.4.mlp h.5.mlp h.6.mlp h.7.mlp h.8.mlp h.9.mlp h.10.mlp h.11.mlp --run_name gpt2-sweep --cross_layer=12 --coalesce_topk=concat --topk_coalesced=False --post_encoder_scale=True --normalize_io=True --lr 3e-4 --optimizer adam --lr_warmup_steps 50
